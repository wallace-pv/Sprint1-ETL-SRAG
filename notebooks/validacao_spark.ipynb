# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("ValidacaoLocal").getOrCreate()


arquivo_csv = 'dados/SARS_01-06/SRAG_01-06.csv'

try:
    df_local = spark.read.csv(arquivo_csv)
    df_local.show(30)
    print("Deu certo")
except Exception as e:
    print(f"\nOcorreu um erro: {e}")

spark.stop()
# Out:
# +--------------------+
# |                 _c0|
# +--------------------+
# |"NU_NOTIFIC";"DT_...|
# |"315778971760";20...|
# |"315778983536";20...|
# |"315778997513";20...|
# |"315779008162";20...|
# |"315779111812";20...|
# |"315779601509";20...|
# |"315779617056";20...|
# |"315779653550";20...|
# |"315779686594";20...|
# |EVOLUI PARA TOT +...|
# |PUERPERA PERMANEC...|
# |"315779694324";20...|
# |DO: DPOC EXACERBA...|
# |"315779702726";20...|
# |"315779708981";20...|
# |"315779714008";20...|
# |"315779727957";20...|
# |"315779731133";20...|
# |"315779746199";20...|
# |"315779752043";20...|
# |"315779788808";20...|
# |"315779802971";20...|
# |"315779871016";20...|
# |"315779876451";20...|
# |"315779879887";20...|
# |"315779882492";20...|
# |"315779885546";20...|
# |"315779889336";20...|
# |"315779995989";20...|
# +--------------------+
# only showing top 30 rows
# Deu certo
